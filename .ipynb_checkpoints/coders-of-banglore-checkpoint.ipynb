# %% [markdown]
# #coaders of banglore

# %%
with open ("finaldata.txt", encoding ="utf-8") as f :
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [chunk for chunk in chunks if len(chunk)>3]

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split("\n")
    username = sep_chunk[0]
    no_of_posts = int(sep_chunk[1].split("post")[0].replace(",",""))
    no_of_followers =float(sep_chunk[2].split("follower")[0].replace(",","").replace("K","").replace("M",""))
    if ("K" in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000)
    elif("M" in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000000)
    else:
       no_of_followers = int(no_of_followers)
    
    
    no_of_following =float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
    if ("K" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000)
    elif("M" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000000)
    else:
        no_of_following = int(no_of_following)
    name = sep_chunk[4]
    if(len(sep_chunk)> 5):
        types_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else: 
        types_of_page = "unknown"
        bio = ""

    #print(username,no_of_posts,no_of_followers,no_of_following,types_of_page,bio)
    return{"username" : username,"no_of_posts": no_of_posts,"no_of_followers": no_of_followers,"no_of_following": no_of_following,"types_of_page": types_of_page,"bio": bio}

#print(parse_chunk(chunks[0]))

# %%
all_chunks = []
for chunk in chunks :
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json
s = json.dumps(all_chunks,indent = 4 )
with open("data.json","w") as f :
    f.write(s)

# %% [markdown]
# #who has maximum posts ?
#
# let's write the coad for find maximum posts

# %%
max_posts = max(all_chunks, key = lambda x : int(x["no_of_posts"]))
max_posts
# Out:
# {'username': 'startuphub_blr',
#  'no_of_posts': 2300,
#  'no_of_followers': 45000,
#  'no_of_following': 120,
#  'types_of_page': 'Media',
#  'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# #who has maximum followers ?
#
# let's write the coad for find maximum followers

# %%
max_followers = max(all_chunks, key = lambda x : int(x["no_of_followers"]))
max_followers
# Out:
# {'username': '_anujsinghal',
#  'no_of_posts': 1785,
#  'no_of_followers': 681000,
#  'no_of_following': 248,
#  'types_of_page': 'Digital creator',
#  'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %%
max_following = max(all_chunks, key = lambda x : int(x["no_of_following"]))
max_following
# Out:
# {'username': 'katiasales2220',
#  'no_of_posts': 107,
#  'no_of_followers': 219,
#  'no_of_following': 1401,
#  'types_of_page': 'Alfabetização e Reforço Escolar',
#  'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['types_of_page'])
print(categories,f"there are {len(categories)} categories" )
# Out:
# {'Tech Creator', 'Investor', 'Educator', 'Artist + Coder', 'Public Figure', 'Cafe Nerd', 'Education', 'Coder', 'Comedy', 'Nonprofit organization', 'Tech', 'Recruiter', 'Full-stack Dev', 'Community', 'Backend Developer', 'Food & Drink', 'Data Scientist', 'Media', 'Blog', 'Frontend Dev', 'Digital creator', 'Writer', 'Developer', 'Personal Blog', 'Data Science', 'Design', 'Lifestyle', 'Cafe Explorer', 'Founder', 'Blogger', 'Software Engineer', 'Entrepreneur', 'Product Manager', 'Engineer'} there are 34 categories
